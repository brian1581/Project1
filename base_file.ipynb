# %%
import pandas as pd
import requests
import numpy as np
import matplotlib.pyplot as plt
import csv
import json

# %%
url = "https://jobs.github.com/positions.json?"
page = "page="
page_num = "0"
df_1 = []
df_2 = []
l = []

# %%
i = 1

while i < 20:
    
    f = (url + page + str(i))
    res = requests.get(f)
    res_json = res.json()

    res_vol = len(res_json)
    
    if (res_vol > 3):
        l = l + res_json
        print(f"Completed API call number {i}")
    else:
        print(f"res was smaller than 3 so we are going to stop the loop and .")
        print(f"final length of response {len(l)}")
        #l = json.dumps(l)
        #print(f"final length of response after jsondumps {len(l)}")
        #print(f"~~~~~~~~~~~~~~~~~~~~")
        break
    
    i += 1

print(l)
# Out:
# Completed API call number 1
# Completed API call number 2
# Completed API call number 3
# Completed API call number 4
# Completed API call number 5
# Completed API call number 6
# res was smaller than 3 so we are going to stop the loop and .
# final length of response 293
# [{'id': '5ceb7560-3be5-446d-a878-1482a7ff0728', 'type': 'Full Time', 'url': 'https://jobs.github.com/positions/5ceb7560-3be5-446d-a878-1482a7ff0728', 'created_at': 'Wed Aug 07 19:54:07 UTC 2019', 'company': 'American Physical Society', 'company_url': None, 'location': 'Ridge', 'title': 'Software Developer', 'description': "<p>Who we are</p>\n<p>The American Physical Society (APS) is a nonprofit membership organization working to advance and diffuse the knowledge of physics through its outstanding research journals, scientific meetings, and education, outreach, advocacy, and international activities. APS represents over 55,000 members, including physicists in academia, national laboratories, and industry in the United States and throughout the world. Society offices are located in College Park, MD (Headquarters), Ridge, NY, and Washington, D.C.</p>\n<p>Position Summary</p>\n<p>The American Physical Society, a leading publisher of scientific journals, based in Suffolk County, LI, is seeking a front end developer. This is an exciting opportunity to apply your strong front end development and UX skills to build applications used in all aspects of scientific publishing.</p>\n<p>We’re a group who happily share knowledge and value other ideas, while working in a bright, modern office with a friendly atmosphere and flat hierarchies. We will challenge you with interesting work while providing you with a collaborative culture in a fast paced environment. Our staff is encouraged to attend industry conferences and we are constantly playing with new tools and use all the latest and greatest technologies, affording you the capability to impact all aspects of your projects.</p>\n<p>You must have excellent English communication skills, be a problem solver and a team player, and be results oriented.  Other incentives for working at APS are great pay, great benefits, generous 403(b), fun company events, commuter benefits, and 3 weeks paid vacation.</p>\n<p><strong>If possible, when applying, please provide code samples and URL's of previous applications you've developed. Candidates who provide links to their GitHub profiles or personal websites with technical articles and/or code samples will receive priority.</strong></p>\n<p><strong>Required Skills</strong></p>\n<ul>\n<li>Expert knowledge of HTML5, CSS3, and associated web standards</li>\n<li>Experience writing modern Javascript (ES6/ES2015, ES2017, Typescript, etc).</li>\n<li>Experience with front-end frameworks such as React or Vue.js</li>\n<li>Experience with modern front-end tooling (Babel, webpack, gulp, parcel, etc.)</li>\n<li>Proficiency in building responsive web applications</li>\n<li>Knowledge of UI/UX design concepts, pattern libraries, style guides, etc.</li>\n<li>Basic command line proficiency (Linux and/or Mac OS X preferred)</li>\n<li>Experience with Git or a similar version control system</li>\n<li>Experience with AWS or similar cloud service providers</li>\n</ul>\n<p><strong>Desired Skills</strong></p>\n<ul>\n<li>Experience doing test driven development with Jest, Jasmine, Mocha/Chai/Sinon, Karma. Integration testing with Selenium.</li>\n<li>Experience with server side development (node.js, express, etc.)</li>\n<li>Basic knowledge of GraphQL</li>\n<li>Experience with additional programming languages (clojurescript, Typescript preferred)</li>\n<li>Accessibility</li>\n</ul>\n<p>The American Physical Society strives to:</p>\n<ul>\n<li>Be the leading voice for physics and an authoritative source of physics information for the advancement of physics and the benefit of humanity.</li>\n<li>Provide effective programs in support of the physics community and the conduct of physics.</li>\n<li>Collaborate with national scientific societies for the advancement of science, science education and the science community.</li>\n<li>Cooperate with international physics societies to promote physics, to support physicists worldwide and to foster international collaboration.</li>\n<li>Promote an ac ...

# %%
l = pd.DataFrame(l)

l.head()

l2 = l.drop(columns=['url', 'company_url','how_to_apply', 'how_to_apply', 'company_logo'])

l2.count()
# Out:
# id             293
# type           293
# created_at     293
# company        293
# location       293
# title          293
# description    293
# dtype: int64

# %%
job_ct = l2['title'].count()

job_ct
# Out:
# 293

# %%
l2 = l2.replace(
    {"Senior Software Engineer (m/f)": "Senior Software Engineer", 
     'Senior Software Engineer - Product': 'Senior Software Engineer',
    'Full Stack Software Engineer': 'Software Engineer',
    'Device Software Engineer at Humane': 'Software Engineer',
    'Media Software Engineer': 'Software Engineer',
    'Mobile Software Engineer (C++) - Philips HUE': 'Software Engineer'})

# l2['title'].value_counts()

eng = len(l2[l2['title'].str.contains('Eng')])
dvlpr = len(l2[l2['title'].str.contains('Dev')])
anlyst = len(l2[l2['title'].str.contains('Analyst')])
science = len(l2[l2['title'].str.contains('Scientist')])
senior = len(l2[l2['title'].str.contains('Sr')])
lead = len(l2[l2['title'].str.contains('Lead')])
remote = len(l2[l2['description'].str.contains('Remote')])
staff = len(l2[l2['title'].str.contains('Staff')])
principal = len(l2[l2['title'].str.contains('Principal')])
staff
# Out:
# 1

# %%
l2.insert(5, 'Title Bucket', 'Other')

# jobs =[]

for job in l2.iterrows():
    if 'Analyst' in job[1]['title']:
        job[1]['Title Bucket'] = 'Analyst'
    elif 'ANALYST' in job[1]['title']:
        job[1]['Title Bucket'] = 'Analyst'
    elif 'analyst' in job[1]['title']:
        job[1]['Title Bucket'] = 'Analyst'
    elif 'Scientist' in job[1]['title']:
        job[1]['Title Bucket'] = 'Scientist'
    elif 'scientist' in job[1]['title']:
        job[1]['Title Bucket'] = 'Scientist'
    elif 'SCIENTIST' in job[1]['title']:
        job[1]['Title Bucket'] = 'Scientist'
    elif 'Dev' in job[1]['title']:
        job[1]['Title Bucket'] = 'Developer'
    elif 'dev' in job[1]['title']:
        job[1]['Title Bucket'] = 'Developer'
    elif 'DEV' in job[1]['title']:
        job[1]['Title Bucket'] = 'Developer'
    elif 'Eng' in job[1]['title']:
        job[1]['Title Bucket'] = 'Engineer'
    elif 'eng' in job[1]['title']:
        job[1]['Title Bucket'] = 'Engineer'
    elif 'ENG' in job[1]['title']:
        job[1]['Title Bucket'] = 'Engineer'
    elif 'Staff' in job[1]['title']:
        job[1]['Title Bucket'] = 'Staff'
    elif 'Principal' in job[1]['title']:
        job[1]['Title Bucket'] = 'Principal'
        
l2.head()
# Out:
#                                      id       type  \
# 0  5ceb7560-3be5-446d-a878-1482a7ff0728  Full Time
# 1  3fa12a8e-a0ae-46d1-9601-b78d41e43737  Full Time
# 2  740ce758-53cc-4f3d-88b9-80aaa92e2105  Full Time
# 3  9e0464b0-a58c-4f37-864f-f8e3fdb8bf6d  Full Time
# 4  2ffe2180-1bf6-4e3f-b7da-f45fd719cbcb  Full Time
#
#                      created_at                    company  \
# 0  Wed Aug 07 19:54:07 UTC 2019  American Physical Society
# 1  Tue Oct 22 18:47:36 UTC 2019               AppraisalFlo
# 2  Tue Oct 22 17:42:36 UTC 2019               Farm Journal
# 3  Tue Oct 22 13:52:28 UTC 2019                    Nexient
# 4  Tue Oct 22 08:26:13 UTC 2019            PlusServer GmbH
#
#                              location Title Bucket  \
# 0                               Ridge    Developer
# 1                             Atlanta    Developer
# 2                             Chicago    Developer
# 3  Dublin, Ohio, United States, 43016        Other
# 4                                Köln        Other
#
#                                    title  \
# 0                     Software Developer
# 1  Senior PHP | MySQL Developer | Remote
# 2                     Software Developer
# 3         Salesforce Technical Architect
# 4     Java Entwickler Front- und Backend
#
#                                          description
# 0  <p>Who we are</p>\n<p>The American Physical So...
# 1  <p>Who we are:</p>\n<p>We represent a business...
# 2  <p><strong>POSITION DESCRIPTION</strong></p>\n...
# 3  <p>All of us rely on software in some form in ...
# 4  <p>Wir bieten die Sicherheit eines Konzerns mi...

# %%
l2.insert(6, 'Senior Bucket', 'Other')

for z in l2.iterrows():
    if 'Lead' in z[1]['title']:
        z[1]['Senior Bucket'] = 'Lead'
    elif 'lead' in z[1]['title']:
        z[1]['Senior Bucket'] = 'Lead'
    elif 'LEAD' in z[1]['title']:
        z[1]['Senior Bucket'] = 'Lead'
    elif 'Senior' in z[1]['title']:
        z[1]['Senior Bucket'] = 'Senior'
    elif 'SENIOR' in z[1]['title']:
        z[1]['Senior Bucket'] = 'Senior'
    elif 'senior' in z[1]['title']:
        z[1]['Senior Bucket'] = 'Senior'
    elif 'Sr' in z[1]['title']:
        z[1]['Senior Bucket'] = 'Senior'
    
l2
# Out:
#                                        id       type  \
# 0    5ceb7560-3be5-446d-a878-1482a7ff0728  Full Time
# 1    3fa12a8e-a0ae-46d1-9601-b78d41e43737  Full Time
# 2    740ce758-53cc-4f3d-88b9-80aaa92e2105  Full Time
# 3    9e0464b0-a58c-4f37-864f-f8e3fdb8bf6d  Full Time
# 4    2ffe2180-1bf6-4e3f-b7da-f45fd719cbcb  Full Time
# ..                                    ...        ...
# 288  40ca8a98-a4bb-11e8-9a40-f75b414612e1  Full Time
# 289  df5b47be-d612-11e8-88f4-50633736745c  Full Time
# 290  da8ad94e-d5f8-11e8-8225-f199d46197fd  Full Time
# 291  95048694-1952-11e8-86d5-38e7f24d7ed9  Full Time
# 292  c37e8b54-d555-11e8-8730-c2f34a443e55  Full Time
#
#                        created_at                    company  \
# 0    Wed Aug 07 19:54:07 UTC 2019  American Physical Society
# 1    Tue Oct 22 18:47:36 UTC 2019               AppraisalFlo
# 2    Tue Oct 22 17:42:36 UTC 2019               Farm Journal
# 3    Tue Oct 22 13:52:28 UTC 2019                    Nexient
# 4    Tue Oct 22 08:26:13 UTC 2019            PlusServer GmbH
# ..                            ...                        ...
# 288  Mon Oct 22 16:33:37 UTC 2018                    Reaktor
# 289  Mon Oct 22 15:56:13 UTC 2018               Constructive
# 290  Mon Oct 22 12:49:21 UTC 2018         www.FaktorZehn.com
# 291  Sun Oct 21 23:46:24 UTC 2018             Analytics Fire
# 292  Sun Oct 21 17:25:33 UTC 2018                   DevsData
#
#                                location Title Bucket Senior Bucket  \
# 0                                 Ridge    Developer         Other
# 1                               Atlanta    Developer        Senior
# 2                               Chicago    Developer         Other
# 3    Dublin, Ohio, United States, 43016        Other         Other
# 4                                  Köln        Other         Other
# ..                                  ...          ...           ...
# 288                            New York    Developer         Other
# 289                       New York City        Other          Lead
# 290                             München        Other        Senior
# 291                              Remote    Developer        Senior
# 292                        Oslo, Norway     Engineer          Lead
#
#                                                  title  \
# 0                                   Software Developer
# 1                Senior PHP | MySQL Developer | Remote
# 2                                   Software Developer
# 3                       Salesforce Technical Architect
# 4                   Java Entwickler Front- und Backend
# ..                                                 ...
# 288  A Challenge for Developers: Solve the Tracking...
# 289  Technology Team Lead, Design Agency for Social...
# 290            Senior Software Entwickler Java (m/w/d)
# 291  SENIOR FULL-STACK DEV WITH RUBY/PYTHON/REACT -...
# 292  Senior Full-Stack JavaScript Engineer/Tech Lea...
#
#                                            description
# 0    <p>Who we are</p>\n<p>The American Physical So...
# 1    <p>Who we are:</p>\n<p>We represent a business...
# 2    <p><strong>POSITION DESCRIPTION</strong></p>\n...
# 3    <p>All of us rely on software in some form in ...
# 4    <p>Wir bieten die Sicherheit eines Konzerns mi...
# ..                                                 ...
# 288  <p><strong>Reaktor is looking for developers w...
# 289  <p>Constructive (<a href="https://constructive...
# 290  <p>Lust auf Veränderung?</p>\n<p>Du bist ein J...
# 291  <p><strong>Job Description</strong></p>\n<p>An...
# 292  <h2>[Senior Full-Stack JS Engineer/Tech Lead w...
#
# [293 rows x 9 columns]

# %%
l2.insert(6, 'Remote?', 'Onsite')

for a in l2.iterrows():
    if 'Remote' in a[1]['location'] or 'Remote' in a[1]['title']:
        a[1]['Remote?'] = 'Remote'
    elif 'Remote' in a[1]['location'] or 'Remote' in a[1]['title']:
        a[1['Remote?']] = 'Remote'
    elif 'Remote' in a[1]['location'] or 'Remote' in a[1]['title']:
        a[1]['Remote?'] = 'Remote'
        
l2
# Out:
#                                        id       type  \
# 0    5ceb7560-3be5-446d-a878-1482a7ff0728  Full Time
# 1    3fa12a8e-a0ae-46d1-9601-b78d41e43737  Full Time
# 2    740ce758-53cc-4f3d-88b9-80aaa92e2105  Full Time
# 3    9e0464b0-a58c-4f37-864f-f8e3fdb8bf6d  Full Time
# 4    2ffe2180-1bf6-4e3f-b7da-f45fd719cbcb  Full Time
# ..                                    ...        ...
# 288  40ca8a98-a4bb-11e8-9a40-f75b414612e1  Full Time
# 289  df5b47be-d612-11e8-88f4-50633736745c  Full Time
# 290  da8ad94e-d5f8-11e8-8225-f199d46197fd  Full Time
# 291  95048694-1952-11e8-86d5-38e7f24d7ed9  Full Time
# 292  c37e8b54-d555-11e8-8730-c2f34a443e55  Full Time
#
#                        created_at                    company  \
# 0    Wed Aug 07 19:54:07 UTC 2019  American Physical Society
# 1    Tue Oct 22 18:47:36 UTC 2019               AppraisalFlo
# 2    Tue Oct 22 17:42:36 UTC 2019               Farm Journal
# 3    Tue Oct 22 13:52:28 UTC 2019                    Nexient
# 4    Tue Oct 22 08:26:13 UTC 2019            PlusServer GmbH
# ..                            ...                        ...
# 288  Mon Oct 22 16:33:37 UTC 2018                    Reaktor
# 289  Mon Oct 22 15:56:13 UTC 2018               Constructive
# 290  Mon Oct 22 12:49:21 UTC 2018         www.FaktorZehn.com
# 291  Sun Oct 21 23:46:24 UTC 2018             Analytics Fire
# 292  Sun Oct 21 17:25:33 UTC 2018                   DevsData
#
#                                location Title Bucket Remote? Senior Bucket  \
# 0                                 Ridge    Developer  Onsite         Other
# 1                               Atlanta    Developer  Remote        Senior
# 2                               Chicago    Developer  Onsite         Other
# 3    Dublin, Ohio, United States, 43016        Other  Onsite         Other
# 4                                  Köln        Other  Onsite         Other
# ..                                  ...          ...     ...           ...
# 288                            New York    Developer  Onsite         Other
# 289                       New York City        Other  Onsite          Lead
# 290                             München        Other  Onsite        Senior
# 291                              Remote    Developer  Remote        Senior
# 292                        Oslo, Norway     Engineer  Onsite          Lead
#
#                                                  title  \
# 0                                   Software Developer
# 1                Senior PHP | MySQL Developer | Remote
# 2                                   Software Developer
# 3                       Salesforce Technical Architect
# 4                   Java Entwickler Front- und Backend
# ..                                                 ...
# 288  A Challenge for Developers: Solve the Tracking...
# 289  Technology Team Lead, Design Agency for Social...
# 290            Senior Software Entwickler Java (m/w/d)
# 291  SENIOR FULL-STACK DEV WITH RUBY/PYTHON/REACT -...
# 292  Senior Full-Stack JavaScript Engineer/Tech Lea...
#
#                                            description
# 0    <p>Who we are</p>\n<p>The American Physical So...
# 1    <p>Who we are:</p>\n<p>We represent a business...
# 2    <p><strong>POSITION DESCRIPTION</strong></p>\n...
# 3    <p>All of us rely on software in some form in ...
# 4    <p>Wir bieten die Sicherheit eines Konzerns mi...
# ..                                                 ...
# 288  <p><strong>Reaktor is looking for developers w...
# 289  <p>Constructive (<a href="https://constructive...
# 290  <p>Lust auf Veränderung?</p>\n<p>Du bist ein J...
# 291  <p><strong>Job Description</strong></p>\n<p>An...
# 292  <h2>[Senior Full-Stack JS Engineer/Tech Lead w...
#
# [293 rows x 10 columns]

# %%
l2.insert(7, 'Degree Indication', 'None Listed')

for c in l2.iterrows():
    if 'Master' in c[1]['description']:
        c[1]['Degree Indication'] = 'Master'
    elif 'master' in c[1]['description']:
        c[1]['Degree Indication'] = 'Master'
    elif 'Bachelor' in c[1]['description']:
        c[1]['Degree Indication'] = 'Bachelor'
    elif 'bachelor' in c[1]['description']:
        c[1]['Degree Indication'] = 'Bachelor'
    elif 'camp' in c[1]['description']:
        c[1]['Degree Indication'] = 'Bootcamp'
l2
# Out:
#                                        id       type  \
# 0    5ceb7560-3be5-446d-a878-1482a7ff0728  Full Time
# 1    3fa12a8e-a0ae-46d1-9601-b78d41e43737  Full Time
# 2    740ce758-53cc-4f3d-88b9-80aaa92e2105  Full Time
# 3    9e0464b0-a58c-4f37-864f-f8e3fdb8bf6d  Full Time
# 4    2ffe2180-1bf6-4e3f-b7da-f45fd719cbcb  Full Time
# ..                                    ...        ...
# 288  40ca8a98-a4bb-11e8-9a40-f75b414612e1  Full Time
# 289  df5b47be-d612-11e8-88f4-50633736745c  Full Time
# 290  da8ad94e-d5f8-11e8-8225-f199d46197fd  Full Time
# 291  95048694-1952-11e8-86d5-38e7f24d7ed9  Full Time
# 292  c37e8b54-d555-11e8-8730-c2f34a443e55  Full Time
#
#                        created_at                    company  \
# 0    Wed Aug 07 19:54:07 UTC 2019  American Physical Society
# 1    Tue Oct 22 18:47:36 UTC 2019               AppraisalFlo
# 2    Tue Oct 22 17:42:36 UTC 2019               Farm Journal
# 3    Tue Oct 22 13:52:28 UTC 2019                    Nexient
# 4    Tue Oct 22 08:26:13 UTC 2019            PlusServer GmbH
# ..                            ...                        ...
# 288  Mon Oct 22 16:33:37 UTC 2018                    Reaktor
# 289  Mon Oct 22 15:56:13 UTC 2018               Constructive
# 290  Mon Oct 22 12:49:21 UTC 2018         www.FaktorZehn.com
# 291  Sun Oct 21 23:46:24 UTC 2018             Analytics Fire
# 292  Sun Oct 21 17:25:33 UTC 2018                   DevsData
#
#                                location Title Bucket Remote?  \
# 0                                 Ridge    Developer  Onsite
# 1                               Atlanta    Developer  Remote
# 2                               Chicago    Developer  Onsite
# 3    Dublin, Ohio, United States, 43016        Other  Onsite
# 4                                  Köln        Other  Onsite
# ..                                  ...          ...     ...
# 288                            New York    Developer  Onsite
# 289                       New York City        Other  Onsite
# 290                             München        Other  Onsite
# 291                              Remote    Developer  Remote
# 292                        Oslo, Norway     Engineer  Onsite
#
#     Degree Indication Senior Bucket  \
# 0         None Listed         Other
# 1            Bachelor        Senior
# 2         None Listed         Other
# 3         None Listed         Other
# 4         None Listed         Other
# ..                ...           ...
# 288       None Listed         Other
# 289       None Listed          Lead
# 290       None Listed        Senior
# 291       None Listed        Senior
# 292       None Listed          Lead
#
#                                                  title  \
# 0                                   Software Developer
# 1                Senior PHP | MySQL Developer | Remote
# 2                                   Software Developer
# 3                       Salesforce Technical Architect
# 4                   Java Entwickler Front- und Backend
# ..                                                 ...
# 288  A Challenge for Developers: Solve the Tracking...
# 289  Technology Team Lead, Design Agency for Social...
# 290            Senior Software Entwickler Java (m/w/d)
# 291  SENIOR FULL-STACK DEV WITH RUBY/PYTHON/REACT -...
# 292  Senior Full-Stack JavaScript Engineer/Tech Lea...
#
#                                            description
# 0    <p>Who we are</p>\n<p>The American Physical So...
# 1    <p>Who we are:</p>\n<p>We represent a business...
# 2    <p><strong>POSITION DESCRIPTION</strong></p>\n...
# 3    <p>All of us rely on software in some form in ...
# 4    <p>Wir bieten die Sicherheit eines Konzerns mi...
# ..                                                 ...
# 288  <p><strong>Reaktor is looking for developers w...
# 289  <p>Constructive (<a href="https://constructive...
# 290  <p>Lust auf Veränderung?</p>\n<p>Du bist ein J...
# 291  <p><strong>Job Description</strong></p>\n<p>An...
# 292  <h2>[Senior Full-Stack JS Engineer/Tech Lead w...
#
# [293 rows x 11 columns]

# %%
sorted_df = l2.sort_values(['Degree Indication'])
bootcamp = sorted_df['Degree Indication']
sorted_df
# Out:
#                                        id       type  \
# 170  45296f64-ec32-11e8-9e1b-5d24b20f1c0f  Full Time
# 54   fa53ecb5-45f9-4242-a662-1858fcff966a  Full Time
# 182  93a08496-e9c8-11e8-8e1e-09934e650343  Full Time
# 29   5086af3e-a27d-40d8-b443-d607a950088d  Full Time
# 31   cb24f618-6f83-47eb-8685-113b3448d616  Full Time
# ..                                    ...        ...
# 127  99ab7a83-f075-4c44-a197-4954598d660a  Full Time
# 128  da96859d-2d4e-4b01-9214-04f29239e5f7  Full Time
# 129  d43f9147-973b-4277-9146-9009db675e92  Full Time
# 131  9e032cc0-8abc-4848-a089-bb1f36293219  Full Time
# 292  c37e8b54-d555-11e8-8730-c2f34a443e55  Full Time
#
#                        created_at  \
# 170  Mon Nov 19 19:40:01 UTC 2018
# 54   Fri Oct 11 22:58:27 UTC 2019
# 182  Fri Nov 16 17:55:45 UTC 2018
# 29   Wed Oct 16 20:44:19 UTC 2019
# 31   Wed Oct 16 13:21:06 UTC 2019
# ..                            ...
# 127  Fri Sep 27 12:06:44 UTC 2019
# 128  Fri Sep 27 10:36:21 UTC 2019
# 129  Fri Sep 27 10:29:39 UTC 2019
# 131  Fri Sep 27 09:50:06 UTC 2019
# 292  Sun Oct 21 17:25:33 UTC 2018
#
#                                                company         location  \
# 170                                    Prosek Partners    Fairfield, CT
# 54   Gurtin Municipal Bond Management, a PIMCO Company        San Diego
# 182                                             Target  Minneapolis, MN
# 29                                          Lift & Co.          Toronto
# 31                                        Pacific Life  Aliso Viejo, CA
# ..                                                 ...              ...
# 127                                    Impero Software           Remote
# 128                                    Impero Software           Remote
# 129                                    Impero Software           Remote
# 131                                      GOhiring GmbH           Berlin
# 292                                           DevsData     Oslo, Norway
#
#     Title Bucket Remote? Degree Indication Senior Bucket  \
# 170    Developer  Onsite          Bachelor         Other
# 54     Developer  Onsite          Bachelor         Other
# 182        Other  Onsite          Bachelor        Senior
# 29      Engineer  Onsite          Bachelor         Other
# 31      Engineer  Onsite          Bachelor          Lead
# ..           ...     ...               ...           ...
# 127     Engineer  Remote       None Listed        Senior
# 128     Engineer  Remote       None Listed        Senior
# 129     Engineer  Remote       None Listed        Senior
# 131    Developer  Onsite       None Listed        Senior
# 292     Engineer  Onsite       None Listed          Lead
#
#                                                  title  \
# 170                                Front End Developer
# 54                Full Stack Developer, C# and Angular
# 182                                  Sr Ad Ops Manager
# 29                                       Data Engineer
# 31     Software Solutions Engineer/Lead/Architect-Java
# ..                                                 ...
# 127                  Senior Software Engineer (Chrome)
# 128                     Senior Automated Test Engineer
# 129                Senior Web Engineer (Ruby on Rails)
# 131               Senior Fullstack Ruby / JS Developer
# 292  Senior Full-Stack JavaScript Engineer/Tech Lea...
#
#                                            description
# 170  <p>Background</p>\n<p>Prosek Partners, one of ...
# 54   <p>Job Description:\nGurtin Municipal Bond Man...
# 182  <p>Target is an iconic brand, a Fortune 50 com...
# 29   <p><strong>Data Engineer</strong></p>\n<p><str...
# 31   <p>For more than 150 years, Pacific Life has o...
# ..                                                 ...
# 127  <p>At Impero, we've been in Education Technolo...
# 128  <p>At Impero, we've been in Education Technolo...
# 129  <p>At Impero, we've been in Education Technolo...
# 131  <p><strong>About us</strong></p>\n<p>We are lo...
# 292  <h2>[Senior Full-Stack JS Engineer/Tech Lead w...
#
# [293 rows x 11 columns]

# %%
rmt_ct = len(sorted_df[sorted_df['Remote?'].str.contains('Remote')])
onsite_ct = len(sorted_df[sorted_df['Remote?'].str.contains('Onsite')])

prct_remote = ((rmt_ct / job_ct) * 100)
prct_onsite = ((onsite_ct / job_ct) * 100)

rmt_df = pd.DataFrame({'Remote %': [prct_remote],'Remote Count': [rmt_ct],
                       'Onsite %': [prct_onsite],'Onsite Count': [onsite_ct]})

# rmt_df['Remote %'] = rmt_df['Remote %'].astype(float).map('{:.2f}%'.format)
# rmt_df['Onsite %'] = rmt_df['Onsite %'].astype(float).map('{:.2f}%'.format)

rmt_df.head()
# Out:
#    Remote %  Remote Count  Onsite %  Onsite Count
# 0  13.31058            39  86.68942           254

# %%
remote = ['Remote', 'Onsite']
remote_jobs = [rmt_df['Remote %'], rmt_df['Onsite %']]
colors = ["red","orange"]

explode = (0,0)

plt.pie(remote_jobs, labels=remote, colors=colors,
        autopct="%1.0f%%", shadow=True, startangle=120)

plt.title('Postings by Remote Work Offered')
plt.axis("equal")
plt.savefig("../remote_jobs.png")
plt.show()
# Out:
# /Users/brian.abbe/anaconda3/envs/Pythondata/lib/python3.6/site-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.

# %%
sr_ct = len(sorted_df[sorted_df['Senior Bucket'].str.contains('Senior')])
lead_ct = len(sorted_df[sorted_df['Senior Bucket'].str.contains('Lead')])
other_ct = len(sorted_df[sorted_df['Senior Bucket'].str.contains('Other')])

sr_prct = ((sr_ct / job_ct) * 100)
lead_prct = ((lead_ct / job_ct) * 100)
other_prct = ((other_ct / job_ct) * 100)

sr_df = pd.DataFrame({'Senior Job %': [sr_prct],'Senior Jobs': [sr_ct],
'Lead Job %': [lead_prct], 'Lead Jobs': [lead_ct], 'Junior/Other Job %': [other_prct],
'Junior/Other Jobs': [other_ct]})

#sr_df['Senior Job %'] = sr_df['Senior Job %'].astype(float).map('{:.2f}%'.format)
#sr_df['Lead Job %'] = sr_df['Lead Job %'].astype(float).map('{:.2f}%'.format)
#sr_df['Junior/Other Job %'] = sr_df['Junior/Other Job %'].astype(float).map('{:.2f}%'.format)

sr_df
# Out:
#    Senior Job %  Senior Jobs  Lead Job %  Lead Jobs  Junior/Other Job %  \
# 0      31.05802           91    5.460751         16           63.481229
#
#    Junior/Other Jobs
# 0                186

# %%
manager = ['Senior', 'Lead', 'Junior/Other Job']
lead_jobs = [sr_df['Senior Job %'], sr_df['Lead Job %'],
               sr_df['Junior/Other Job %']]
colors = ["blue","red","green"]
explode = (0,0,0)

plt.pie(lead_jobs, labels=manager, colors=colors,
        autopct="%1.0f%%", shadow=True, startangle=120)

plt.title('Senior/Lead by Degree Mentioned')
plt.axis("equal")
plt.savefig("../senior_jobs.png")
plt.show()
# Out:
# /Users/brian.abbe/anaconda3/envs/Pythondata/lib/python3.6/site-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.

# %%
# sorted_df = sorted_df.reset_index()
analyst_ct = len(sorted_df[sorted_df['Title Bucket'].str.contains('Analyst')])
eng_ct = len(sorted_df[sorted_df['Title Bucket'].str.contains('Engineer')])
dvlpr_ct = len(sorted_df[sorted_df['Title Bucket'].str.contains('Developer')])
scientist_ct = len(sorted_df[sorted_df['Title Bucket'].str.contains('Scientist')])
staff_ct = len(sorted_df[sorted_df['Title Bucket'].str.contains('Staff')])
principal_ct = len(sorted_df[sorted_df['Title Bucket'].str.contains('Scientist')])
other2_ct = len(sorted_df[sorted_df['Title Bucket'].str.contains('Other')])

analyst_prct = ((analyst_ct / job_ct) * 100)
eng_prct = ((eng_ct / job_ct) * 100)
dvlpr_prct = ((dvlpr_ct / job_ct) * 100)
scientist_prct = ((scientist_ct / job_ct) * 100)
staff_prct = ((staff_ct / job_ct) * 100)
principal_prct = ((principal_ct / job_ct) * 100)
other2_prct = ((other2_ct / job_ct) * 100)
 

title_df = pd.DataFrame({'Analyst Job %': [analyst_prct],'Analyst Jobs': [analyst_ct],
'Engineer Job %': [eng_prct], 'Engineer Jobs': [eng_ct], 'Developer Job %': [dvlpr_prct],
'Developer Jobs': [dvlpr_ct], 'Scientist Job %': [scientist_prct], 'Scientist Jobs': [scientist_ct],
'Staff Jobs': [staff_ct], 'Staff Job %': [staff_prct], 'Principal Jobs': [principal_ct], 'Principal Job %':
[principal_prct], 'Other Jobs': [other2_ct], 'Other Job %': [other2_prct]})

#title_df['Engineer Job %'] = title_df['Engineer Job %'].astype(float).map('{:.2f}%'.format)
#title_df['Analyst Job %'] = title_df['Analyst Job %'].astype(float).map('{:.2f}%'.format)
#title_df['Developer Job %'] = title_df['Developer Job %'].astype(float).map('{:.2f}%'.format)
#title_df['Scientist Job %'] = title_df['Scientist Job %'].astype(float).map('{:.2f}%'.format)
#title_df['Staff Job %'] = title_df['Staff Job %'].astype(float).map('{:.2f}%'.format)
#title_df['Principal Job %'] = title_df['Principal Job %'].astype(float).map('{:.2f}%'.format)
#title_df['Other Jobs %'] = title_df['Other Jobs %'].astype(float).map('{:.2f}%'.format)
# Out:
#    Analyst Job %  Analyst Jobs  Engineer Job %  Engineer Jobs  \
# 0       1.365188             4       35.836177            105
#
#    Developer Job %  Developer Jobs  Scientist Job %  Scientist Jobs  \
# 0        42.662116             125         0.341297               1
#
#    Staff Jobs  Staff Job %  Principal Jobs  Principal Job %  Other Jobs  \
# 0           0          0.0               1         0.341297          56
#
#    Other Job %
# 0    19.112628

# %%
job_titles = [scientist_ct, principal_ct, analyst_ct, other2_ct,
              eng_ct, dvlpr_ct]
titles = ['Scientist', 'Principal', 'Analyst', 'Other', 'Engineer', 'Developer']
y_pos = np.arange(len(titles))
 
# Create horizontal bars
plt.barh(y_pos, job_titles, color='rygb', zorder=2)
 
# Create names on the y-axis
plt.yticks(y_pos, titles)
plt.xlabel("Job Count by Title")
plt.ylabel("Job Titles")
plt.title('Jobs by Title Posted')
 
# Show graphic
plt.show()
plt.savefig("../jobs_by_title.png")
titles = ['Engineer', 'Developer', 'Analyst', 'Scientist', 'Staff', 'Principal', 'Other']
job_titles = [eng_ct, dvlpr_ct, other2_ct,
              analyst_ct, staff_ct, principal_ct,
              scientist_ct]

# %%
# Degree Preference

master_ct = len(l2[l2['Degree Indication'].str.contains("Master")])
master_prct = (master_ct / job_ct) * 100

bach_ct = len(l2[l2['Degree Indication'].str.contains('Bachelor')])
bach_prct = (bach_ct / job_ct) * 100

boot_ct = len(l2[l2['Degree Indication'].str.contains('Bootcamp')])
boot_prct = (boot_ct / job_ct) * 100

none_ct = len(l2[l2['Degree Indication'].str.contains('None Listed')])
none_prct = (none_ct / job_ct) * 100

degree_df = pd.DataFrame({'Master Job Percent': [master_prct], 'Bachelor Job Percent': [bach_prct],
                          'Bootcamp Job Percent': [boot_prct], 'No Degree Listed Job Percent': [none_prct]})
              
#degree_df['Master Job Percent'] = degree_df['Master Job Percent'].astype(float).map('{:.2f}%'.format)
#degree_df['Bachelor Job Percent'] = degree_df['Bachelor Job Percent'].astype(float).map('{:.2f}%'.format)
#degree_df['Bootcamp Job Percent'] = degree_df['Bootcamp Job Percent'].astype(float).map('{:.2f}%'.format)
#degree_df['No Degree Listed Job Percent'] = degree_df['No Degree Listed Job Percent'].astype(float).map('{:.2f}%'.format)
# Out:
# 0    15.017065
# Name: Master Job Percent, dtype: float64

# %%
degrees = ['Master', 'Bachelor', 'Bootcamp', 'None Listed']
degree_jobs = [degree_df['Master Job Percent'], degree_df['Bachelor Job Percent'],
               degree_df['Bootcamp Job Percent'], degree_df['No Degree Listed Job Percent']]
colors = ["blue","red","green","orange"]
explode = (0,0,0,0)

plt.pie(degree_jobs, labels=degrees, colors=colors,
        autopct="%1.0f%%", shadow=True, startangle=120)

plt.title('Postings by Degree Discussed')
plt.axis("equal")
plt.savefig("../jobs_by_degree.png")
plt.show()
# Out:
# /Users/brian.abbe/anaconda3/envs/Pythondata/lib/python3.6/site-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.

# %%
# Benefits

child_ct = len(l2[l2['description'].str.contains('Child')])
child2_ct = len(l2[l2['description'].str.contains('child')])
total_child = child_ct + child2_ct
child_prct = (total_child / job_ct) * 100

stock_ct = len(l2[l2['description'].str.contains('Stock')])
stock2_ct = len(l2[l2['description'].str.contains('stock')])
total_stock = stock_ct + stock2_ct
stock_prct = (total_stock / job_ct) * 100

comp_ct = len(l2[l2['description'].str.contains('Competitive salary')])
comp2_ct = len(l2[l2['description'].str.contains('competitive salary')])
comp3_ct = len(l2[l2['description'].str.contains('competitive compensation package')])
total_comp = comp_ct + comp2_ct + comp3_ct
comp_prct = (total_comp / job_ct) * 100

benefit_df = pd.DataFrame({'Offers Stock Options': [total_stock], 'Offers Child Care': [total_child],
                           'Stock Option %': [stock_prct], 'Child Care %': [child_prct],
                          'Competitive Salaries': [total_comp], 'Competitive Salary by %': [comp_prct]})

# benefit_df['Stock Option %'] = benefit_df['Stock Option %'].astype(float).map('{:.2f}%'.format)
# benefit_df['Child Care %'] = benefit_df['Child Care %'].astype(float).map('{:.2f}%'.format)
# benefit_df['Competitive Salary by %'] = benefit_df['Competitive Salary by %'].astype(float).map('{:.2f}%'.format)

benefit_df
# Out:
#    Offers Stock Options  Offers Child Care  Stock Option %  Child Care %  \
# 0                    12                 12        4.095563      4.095563
#
#    Competitive Salaries  Competitive Salary by %
# 0                    33                11.262799

# %%
benefits = ['Child Care', 'Stock Options', 'Competitilve Salary']
benefit_cts = [total_stock, total_child,
               total_comp]
x_axis = np.arange(len(benefits))
 
# Create horizontal bars
plt.bar(x_axis, benefit_cts, color='rgb', zorder=2)
 
# Create names on the y-axis
plt.xticks(x_axis, benefits)
plt.xlim(-0.75, len(x_axis)-0.25)
plt.xlabel("Extra Benefits")
plt.ylabel("Number of Jobs Offering")
plt.ylim(0, max(benefit_cts)+5)
plt.title("Extra Benefits Offered by Postings")
 
# Show graphic
plt.savefig("../benefits_by_job.png")
plt.show()

# %%
grouped1 = sorted_df.groupby(['Degree Indication', 'Senior Bucket'])

bach_lead = 0
bach_sr = 0
master_lead = 0
master_sr = 0

for d in l2.iterrows():
    if 'Bachelor' in d[1]['Degree Indication'] and 'Lead' in d[1]['Senior Bucket']:
        bach_lead += 1
    elif 'Bachelor' in d[1]['Degree Indication'] and 'Senior' in d[1]['Senior Bucket']:
        bach_sr += 1
    elif 'Master' in d[1]['Degree Indication'] and 'Lead' in d[1]['Senior Bucket']:
        master_lead += 1
    elif 'Master' in d[1]['Degree Indication'] and 'Senior' in d[1]['Senior Bucket']:
        master_sr += 1

# %%
grouped2 = sorted_df.groupby(['Degree Indication', 'Title Bucket'])

bach_analyst = 0
bach_dvlpr = 0
bach_eng = 0
master_analyst = 0
master_dvlpr = 0
master_eng = 0

for e in sorted_df.iterrows():
    if 'Bachelor' in e[1]['Degree Indication'] and 'Analyst' in e[1]['Title Bucket']:
        bach_analyst += 1
    elif 'Bachelor' in e[1]['Degree Indication'] and 'Developer' in e[1]['Title Bucket']:
        bach_dvlpr += 1
    elif 'Bachelor' in e[1]['Degree Indication'] and 'Engineer' in e[1]['Title Bucket']:
        bach_eng += 1
    elif 'Master' in e[1]['Degree Indication'] and 'Analyst' in e[1]['Title Bucket']:
        master_analyst += 1
    elif 'Master' in e[1]['Degree Indication'] and 'Developer' in e[1]['Title Bucket']:
        master_dvlpr += 1
    elif 'Master' in e[1]['Degree Indication'] and 'Engineer' in e[1]['Title Bucket']:
        master_eng += 1

# %%
# Null hypothesis. If there is no correlation between degree level and working remote, 
# we should see no relationship between remote work jobs and degree level

grouped2 = sorted_df.groupby(['Degree Indication', 'Title Bucket'])

bach_remote = 0
bach_onsite = 0
master_remote = 0
master_onsite = 0
none_remote = 0
none_onsite = 0

for f in sorted_df.iterrows():
    if 'Bachelor' in f[1]['Degree Indication'] and 'Remote' in f[1]['Remote?']:
        bach_remote += 1
    elif 'Bachelor' in f[1]['Degree Indication'] and 'Onsite' in f[1]['Remote?']:
        bach_onsite += 1
    elif 'Master' in f[1]['Degree Indication'] and 'Remote' in f[1]['Remote?']:
        master_remote += 1
    elif 'Master' in f[1]['Degree Indication'] and 'Onsite' in f[1]['Remote?']:
        master_onsite += 1
    elif 'None Listed' in f[1]['Degree Indication'] and 'Remote' in f[1]['Remote?']:
        none_remote += 1
    elif 'None Listed' in f[1]['Degree Indication'] and 'Onsite' in f[1]['Remote?']:
        none_onsite += 1
# Out:
# 3
# 30
# 4
# 40
# 32
# 181

# %%
# Degree breakdown pie chart
rmt_deg = ['Remote BS Jobs', 'Onsite BS Jobs', 'Remote MS Jobs',
           'Onsite MS Jobs', 'Remote Non-Degree Jobs', 'Onsite Non-Degree Jobs']
remote_onsite = [bach_remote, bach_onsite, master_remote, master_onsite,
           none_remote, none_onsite]
x_axis = np.arange(len(rmt_deg))
 
# Create horizontal bars
plt.bar(x_pos, remote_onsite, color='rygb', zorder=2)
 
# Create names on the y-axis
plt.xticks(x_pos, rmt_deg, rotation=45)
plt.xlim(-0.75, len(x_axis)-0.25)
plt.xlabel("Job Count by Title")
plt.ylabel("Number of Jobs")
plt.ylim(0, max(remote_onsite)+10)
plt.title("Remote/Onsite Jobs by Degree")
 
# Show graphic
plt.show()
plt.savefig("../remote_by_degree.png")
